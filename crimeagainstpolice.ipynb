# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
import plotly.graph_objects as go

# %%
crime =pd.read_csv("13_Police_killed_or_injured_on_duty2001_2010.csv")
crime
# Out:
#                       Area_Name  Year                         Group_Name  \
# 0     Andaman & Nicobar Islands  2001  Police - Assistant Sub-Inspectors
# 1                Andhra Pradesh  2001  Police - Assistant Sub-Inspectors
# 2             Arunachal Pradesh  2001  Police - Assistant Sub-Inspectors
# 3                         Assam  2001  Police - Assistant Sub-Inspectors
# 4                         Bihar  2001  Police - Assistant Sub-Inspectors
# ...                         ...   ...                                ...
# 2445                 Tamil Nadu  2010                     Police - Total
# 2446                    Tripura  2010                     Police - Total
# 2447              Uttar Pradesh  2010                     Police - Total
# 2448                Uttarakhand  2010                     Police - Total
# 2449                West Bengal  2010                     Police - Total
#
#                          Sub_Group_Name  Police_Injured_By_Criminals  \
# ...

# %%
crime.columns = crime.columns.str.strip()

# %%
crime.columns
# Out:
# Index(['Area_Name', 'Year', 'Group_Name', 'Sub_Group_Name',
#        'Police_Injured_By_Criminals', 'Police_Injured_By_Riotous_Mobs',
#        'Police_Injured_In_Accidents',
#        'Police_Injured_In_Dacoity_OperationsOther_raids',
#        'Police_Injured_In_TerroristsExtremists_Operations',
#        'Police_Injured_On_Border_Duties', 'Police_Injured_Total_Policemen',
#        'Police_Killed_By_Criminals', 'Police_Killed_By_Riotous_Mobs',
#        'Police_Killed_In_Accidents',
#        'Police_Killed_In_Dacoity_OperationsOther_raids',
#        'Police_Killed_In_TerroristsExtremists_Operations',
#        'Police_Killed_On_Border_Duties', 'Police_Killed_Total_Policemen'],
#       dtype='object')

# %%
crime.isnull().sum()
# Out:
# Area_Name                                            0
# Year                                                 0
# Group_Name                                           0
# Sub_Group_Name                                       0
# Police_Injured_By_Criminals                          0
# Police_Injured_By_Riotous_Mobs                       0
# Police_Injured_In_Accidents                          0
# Police_Injured_In_Dacoity_OperationsOther_raids      0
# Police_Injured_In_TerroristsExtremists_Operations    0
# Police_Injured_On_Border_Duties                      0
# Police_Injured_Total_Policemen                       0
# Police_Killed_By_Criminals                           0
# Police_Killed_By_Riotous_Mobs                        0
# Police_Killed_In_Accidents                           0
# Police_Killed_In_Dacoity_OperationsOther_raids       0
# Police_Killed_In_TerroristsExtremists_Operations     0
# Police_Killed_On_Border_Duties                       0
# ...

# %%
crime_columns=['Police_Injured_By_Criminals', 'Police_Injured_By_Riotous_Mobs',
       'Police_Injured_In_Accidents',
       'Police_Injured_In_Dacoity_OperationsOther_raids',
       'Police_Injured_In_TerroristsExtremists_Operations',
       'Police_Injured_On_Border_Duties', 'Police_Injured_Total_Policemen',
       'Police_Killed_By_Criminals', 'Police_Killed_By_Riotous_Mobs',
       'Police_Killed_In_Accidents',
       'Police_Killed_In_Dacoity_OperationsOther_raids',
       'Police_Killed_In_TerroristsExtremists_Operations',
       'Police_Killed_On_Border_Duties', 'Police_Killed_Total_Policemen']

# %%
crime_area=crime.groupby('Area_Name',as_index=False)[crime_columns].sum().sort_values(by='Police_Killed_Total_Policemen',ascending=False)

# %%
crime_year= crime.groupby('Year',as_index=False)[crime_columns].sum().sort_values(by='Police_Killed_Total_Policemen',ascending=False)

# %%
crime_subgroup =crime.groupby('Sub_Group_Name',as_index=False)[crime_columns].sum().sort_values(by='Police_Killed_Total_Policemen',ascending=False)

# %%
for crime in crime_columns:
    sorted_crime =crime_area.sort_values(crime,ascending=False)
    fig= px.bar(sorted_crime,x ="Area_Name",y=crime,title = crime.replace("_"," "),
          labels={"Area_Name":"State/ut",crime:"no of cases"},
          hover_data={"Area_Name":True,crime:True})
    
    fig.update_layout(xaxis_title ="State/UT",
                     yaxis_title = crime,
                     yaxis_type ="log",
                     height =800,
                     width =1000)
    fig.show()
# Out:
# <div>                            <div id="a55f3543-53d3-4e79-bd3e-be123382a441" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a55f3543-53d3-4e79-bd3e-be123382a441")) {                    Plotly.newPlot(                        "a55f3543-53d3-4e79-bd3e-be123382a441",                        [{"alignmentgroup":"True","hovertemplate":"State/ut=%{x}<br>no of cases=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Kerala","Rajasthan","Madhya Pradesh","Maharashtra","Uttar Pradesh","Karnataka","West Bengal","Delhi","Jammu & Kashmir","Tamil Nadu","Odisha","Andhra Pradesh","Gujarat","Puducherry","Bihar","Chandigarh","Punjab","
# ...

# %%
for crime in crime_columns:
    sorted_year =crime_year.sort_values(crime,ascending=False)
    fig = px.bar(sorted_year,y=crime,x ='Year',title =crime.replace("_"," "), 
                color = crime,
                labels={'Year':'Year',crime:crime},
                hover_data={'Year':True,crime:True},
                color_continuous_scale="viridis")
    fig.update_layout(xaxis_title = crime,
                     yaxis_title ="Year",
                     height =600,
                     width =1000)
                    
                     
                    
    fig.show()
# Out:
# <div>                            <div id="b6095365-afe8-4736-9cf6-bc244d8c4f00" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6095365-afe8-4736-9cf6-bc244d8c4f00")) {                    Plotly.newPlot(                        "b6095365-afe8-4736-9cf6-bc244d8c4f00",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}<br>Police_Injured_By_Criminals=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[1936,1860,1542,1174,1150,1082,962,902,840,806],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2009,2010,2002,2001,2007,2008,2003,2004,2005,2006],"xaxis":"x","y":[1936,1860,1542,1174,1150,1082,962,902,840,806],"yaxis":"y","
# ...

# %%
for crime in crime_columns:
    fig= px.bar(crime_subgroup, x = crime, y ='Sub_Group_Name',title = crime.replace("_"," "),orientation ="h",
               color=crime,
               color_continuous_scale="viridis",
               labels={crime:crime,'Sub_Group_Name':'category'},
               hover_data={crime:True,'Sub_Group_Name':True})
    fig.update_layout(xaxis_title=crime,
                     yaxis_title="category",
                     yaxis=dict(autorange ="reversed"),
                     height =800,
                     width =1000)
    fig.show()
# Out:
# <div>                            <div id="a03ebfae-6c44-4ef1-9ce5-67d8f3dc4b19" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a03ebfae-6c44-4ef1-9ce5-67d8f3dc4b19")) {                    Plotly.newPlot(                        "a03ebfae-6c44-4ef1-9ce5-67d8f3dc4b19",                        [{"alignmentgroup":"True","hovertemplate":"Police_Injured_By_Criminals=%{marker.color}<br>category=%{y}<extra></extra>","legendgroup":"","marker":{"color":[6127,3701,935,524,655,190,122],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[6127,3701,935,524,655,190,122],"xaxis":"x","y":["7. Total Police Killed or Injured","1. Constables","2. Head Constables","3. Assistant Sub-I
# ...
